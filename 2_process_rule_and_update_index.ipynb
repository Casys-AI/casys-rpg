# %%
# 1. Installation des Bibliothèques
# !pip install langchain faiss-cpu openai tqdm python-dotenv

# 2. Importer les Bibliothèques et Charger les Variables d'Environnement
import os
import json
import time
import re
import faiss
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed
from langchain.embeddings import OpenAIEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain import OpenAI, LLMChain
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from dotenv import load_dotenv

# Charger les variables d'environnement
load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("La clé API OpenAI n'a pas été trouvée dans le fichier .env")

os.environ["OPENAI_API_KEY"] = openai_api_key

jsonl_path = 'data/decision_examples.jsonl'
sections_dir = 'data/sections'
output_directory = 'data/rules'

# Dossier dédié à l'index decision_index
index_dir = 'data/index/decision_index'
faiss_index_path = os.path.join(index_dir, 'decision_index.faiss')
docstore_path = os.path.join(index_dir, 'docstore.json')

if not os.path.exists(jsonl_path):
    raise FileNotFoundError(f"Le fichier {jsonl_path} n'a pas été trouvé.")

jsonl_mtime = os.path.getmtime(jsonl_path)
index_exists = os.path.exists(faiss_index_path) and os.path.exists(docstore_path)

recreate_index = False
if index_exists:
    faiss_mtime = os.path.getmtime(faiss_index_path)
    if jsonl_mtime > faiss_mtime:
        print("Le fichier JSONL a été modifié après la dernière mise à jour de l'index FAISS.")
        recreate_index = True
    else:
        print("L'index FAISS est à jour.")
else:
    print("L'index FAISS n'existe pas et sera créé.")
    recreate_index = True

def create_or_update_index():
    data = []
    with open(jsonl_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                obj = json.loads(line)
                data.append(obj)
    
    # Construire une liste de textes à partir de l'entrée
    texts = []
    for entry in data:
        if 'text' in entry:
            texts.append(entry['text'])
        elif 'messages' in entry and isinstance(entry['messages'], list):
            combined = "\n".join(msg["content"] for msg in entry["messages"] if "content" in msg)
            if combined.strip():
                texts.append(combined)

    if not texts:
        print("Aucun texte ni messages pour construire l'index.")
        return None, None, None

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,
        chunk_overlap=100,
        separators=["\n\n", "\n", " ", ""]
    )
    
    all_chunks = []
    for t in texts:
        all_chunks.extend(text_splitter.split_text(t))
    
    embeddings = OpenAIEmbeddings()
    embedding_vectors = embeddings.embed_documents(all_chunks)
    if not embedding_vectors:
        print("Aucune embedding générée.")
        return None, None, None

    embedding_dim = len(embedding_vectors[0])
    
    index = faiss.IndexFlatL2(embedding_dim)
    index.add(np.array(embedding_vectors).astype('float32'))
    
    docstore = {str(i): chunk for i, chunk in enumerate(all_chunks)}
    
    os.makedirs(index_dir, exist_ok=True)
    faiss.write_index(index, faiss_index_path)
    print(f"Index FAISS sauvegardé dans {faiss_index_path}.")
    
    with open(docstore_path, 'w', encoding='utf-8') as f:
        json.dump(docstore, f)
    print(f"Docstore sauvegardé dans {docstore_path}.")
    
    return index, docstore, embeddings

if recreate_index:
    index, docstore, embeddings = create_or_update_index()
    if index is None:
        raise SystemExit("Impossible de créer l'index RAG (pas de texte).")
else:
    if not (os.path.exists(faiss_index_path) and os.path.exists(docstore_path)):
        print("Index ou docstore manquant, recréez l'index.")
        raise SystemExit
    index = faiss.read_index(faiss_index_path)
    with open(docstore_path, 'r', encoding='utf-8') as f:
        docstore = json.load(f)
    embeddings = OpenAIEmbeddings()
    print("Index FAISS et docstore chargés avec succès.")

def process_section(section_number: int):
    """
    Lis la section 'section_number' depuis data/sections/{section_number}.md
    Interroge le RAG pour obtenir des exemples ou des retours de joueurs, etc., 
    pour comprendre comment séparer l'histoire des règles ludiques.
    Les informations du RAG ne doivent pas être incluses dans le résultat final.
    La sortie finale doit contenir uniquement les règles spécifiques à cette section 
    (choix du joueur, stats, combats, énigmes...).
    """
    markdown_path = os.path.join(sections_dir, f"{section_number}.md")
    if not os.path.exists(markdown_path):
        print(f"La section {section_number} n'existe pas.")
        return

    with open(markdown_path, 'r', encoding='utf-8') as f:
        section_content = f.read()

    # Requête pour obtenir des instructions d'aide (RAG)
    query = ("Donne des exemples pour distinguer l'histoire du livre dont vous êtes le héros "
             "des règles, choix et décisions purement ludiques. Aide-moi à comprendre, mais "
             "je n'intégrerai pas ces exemples dans le résultat final.")
    query_embedding = embeddings.embed_query(query)
    query_vector = np.array([query_embedding]).astype('float32')

    k = 5
    distances, indices = index.search(query_vector, k)

    retrieved_texts = [docstore[str(i)] for i in indices[0] if str(i) in docstore]
    rag_instructions = "\n\n".join(retrieved_texts)

    prompt_template = """
Tu es un assistant chargé d'extraire les règles du jeu présentées dans une section d'un livre dont vous êtes le héros.
Le texte RAG ci-dessous fournit des exemples pour t'aider à comprendre comment séparer l'histoire des vraies règles du jeu.
Ne reprends pas ces exemples dans le résultat final, ils sont juste pour t'aider à comprendre.

RAG (exemples, ne pas les intégrer dans le résultat) :
{rag_instructions}

Section :
{section_content}

Instructions :
- Distingue l'histoire (description, narration) des éléments ludiques (choix du joueur, gain/perte de stats, argent, chemins à prendre, combat, énigme...).
- N'inclus que les règles et décisions spécifiques à cette section.
- Formate les règles en Markdown, par exemple :
  - Choix 1: ...
  - Endurance, CHance, Habileté +x si ...
  - Gagner, perdre de l'argent si
  - choisir cette action mène à ...
  - devoir se battre contre un monstre si
  - si je gagne une partie, je ...
  
Extrais uniquement ces éléments ludiques propres à cette section, sans reprendre les exemples du RAG.
"""
    prompt = PromptTemplate(
        template=prompt_template,
        input_variables=["rag_instructions", "section_content"]
    )

    llm = ChatOpenAI(
        temperature=0,
        openai_api_key=openai_api_key,
        model_name="gpt-4o-mini"
    )
    chain = LLMChain(llm=llm, prompt=prompt)

    rules = chain.run(rag_instructions=rag_instructions, section_content=section_content)

    os.makedirs(output_directory, exist_ok=True)
    output_filename = f'section_{section_number}_rule.md'
    output_path = os.path.join(output_directory, output_filename)

    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(rules)

    print(f"Les règles de la section {section_number} ont été enregistrées dans {output_path}")

# Par exemple, traiter [1,48,164] , ou "all"
sections_to_process = "all"

if sections_to_process == "all":
    all_files = os.listdir(sections_dir)
    md_files = [f for f in all_files if f.endswith(".md")]
    all_sections = []
    for mf in md_files:
        m = re.search(r'(\d+)\.md', mf)
        if m:
            sec_num = int(m.group(1))
            all_sections.append(sec_num)
    sections_to_process = sorted(all_sections)
elif isinstance(sections_to_process, int):
    sections_to_process = [sections_to_process]

# Utilisation du multi-threading
# Nombre de threads = min(nombre de sections, 4) par exemple
from concurrent.futures import ThreadPoolExecutor, as_completed

num_threads = min(len(sections_to_process), 4)

with ThreadPoolExecutor(max_workers=num_threads) as executor:
    futures = {executor.submit(process_section, sec): sec for sec in sections_to_process}
    for future in as_completed(futures):
        sec = futures[future]
        try:
            future.result()
        except Exception as e:
            print(f"Erreur lors du traitement de la section {sec}: {e}")
# Out:
# L'index FAISS est à jour.
# Index FAISS et docstore chargés avec succès.
# Les règles de la section 1 ont été enregistrées dans data/rules\section_1_rule.md
# Les règles de la section 4 ont été enregistrées dans data/rules\section_4_rule.md
# Les règles de la section 2 ont été enregistrées dans data/rules\section_2_rule.md
# Les règles de la section 3 ont été enregistrées dans data/rules\section_3_rule.md
# Les règles de la section 5 ont été enregistrées dans data/rules\section_5_rule.md
# Les règles de la section 7 ont été enregistrées dans data/rules\section_7_rule.md
# Les règles de la section 6 ont été enregistrées dans data/rules\section_6_rule.md
# Les règles de la section 8 ont été enregistrées dans data/rules\section_8_rule.md
# Les règles de la section 9 ont été enregistrées dans data/rules\section_9_rule.md
# Les règles de la section 10 ont été enregistrées dans data/rules\section_10_rule.md
# Les règles de la section 11 ont été enregistrées dans data/rules\section_11_rule.md
# Les règles de la section 12 ont été enregistrées dans data/rules\section_12_rule.md
# Les règles de la section 13 ont été enregistrées dans data/rules\section_13_rule.md
# Les règles de la section 14 ont été enregistrées dans data/rules\section_14_rule.md
# Les règles de la section 15 ont été enregistrées dans data/rules\section_15_rule.md
# Les règles de la section 16 ont été enregistrées dans data/rules\section_16_rule.md
# Les règles de la section 19 ont été enregistrées dans data/rules\section_19_rule.md
# Les règles de la section 18 ont été enregistrées dans data/rules\section_18_rule.md
# Les règles de la section 17 ont été enregistrées dans data/rules\section_17_rule.md
# Les règles de la section 20 ont été enregistrées dans data/rules\section_20_rule.md
# Les règles de la section 21 ont été enregistrées dans data/rules\section_21_rule.md
# Les règles de la section 23 ont été enregistrées dans data/rules\section_23_rule.md
# Les règles de la section 24 ont été enregistrées dans data/rules\section_24_rule.md
# Les règles de la section 25 ont été enregistrées dans data/rules\section_25_rule.md
# Les règles de la section 26 ont été enregistrées dans data/rules\section_26_rule.md
# Les règles de la section 27 ont été enregistrées dans data/rules\section_27_rule.md
# Les règles de la section 22 ont été enregistrées dans data/rules\section_22_rule.md
# Les règles de la section 28 ont été enregistrées dans data/rules\section_28_rule.md
# Les règles de la section 29 ont été enregistrées dans data/rules\section_29_rule.md
# Les règles de la section 31 ont été enregistrées dans data/rules\section_31_rule.md
# Les règles de la section 30 ont été enregistrées dans data/rules\section_30_rule.md
# Les règles de la section 32 ont été enregistrées dans data/rules\section_32_rule.md
# Les règles de la section 34 ont été enregistrées dans data/rules\section_34_rule.md
# Les règles de la section 33 ont été enregistrées dans data/rules\section_33_rule.md
# Les règles de la section 36 ont été enregistrées dans data/rules\section_36_rule.md
# Les règles de la section 37 ont été enregistrées dans data/rules\section_37_rule.md
# Les règles de la section 39 ont été enregistrées dans data/rules\section_39_rule.md
# Les règles de la section 38 ont été enregistrées dans data/rules\section_38_rule.md
# Les règles de la section 35 ont été enregistrées dans data/rules\section_35_rule.md
# Les règles de la section 40 ont été enregistrées dans data/rules\section_40_rule.md
# Les règles de la section 41 ont été enregistrées dans data/rules\section_41_rule.md
# Les règles de la section 42 ont été enregistrées dans data/rules\section_42_rule.md
# Les règles de la section 45 ont été enregistrées dans data/rules\section_45_rule.md
# Les règles de la section 44 ont été enregistrées dans data/rules\section_44_rule.md
# Les règles de la section 46 ont été enregistrées dans data/rules\section_46_rule.md
# Les règles de la section 47 ont été enregistrées dans data/rules\section_47_rule.md
# Les règles de la section 43 ont été enregistrées dans data/rules\section_43_rule.md
# Les règles de la section 49 ont été enregistrées dans data/rules\section_49_rule.md
# Les règles de la section 48 ont été enregistrées dans data/rules\section_48_rule.md
# Les règles de la section 51 ont été enregistrées dans data/rules\section_51_rule.md
# Les règles de la section 50 ont été enregistrées dans data/rules\section_50_rule.md
# Les règles de la section 52 ont été enregistrées dans data/rules\section_52_rule.md
# Les règles de la section 53 ont été enregistrées dans data/rules\section_53_rule.md
# Les règles de la section 54 ont été enregistrées dans data/rules\section_54_rule.md
# Les règles de la section 55 ont été enregistrées dans data/rules\section_55_rule.md
# Les règles de la section 57 ont été enregistrées dans data/rules\section_57_rule.md
# Les règles de la section 56 ont été enregistrées dans data/rules\section_56_rule.md
# Les règles de la section 58 ont été enregistrées dans data/rules\section_58_rule.md
# Les règles de la section 60 ont été enregistrées dans data/rules\section_60_rule.md
# Les règles de la section 61 ont été enregistrées dans data/rules\section_61_rule.md
# Les règles de la section 62 ont été enregistrées dans data/rules\section_62_rule.md
# Les règles de la section 63 ont été enregistrées dans data/rules\section_63_rule.md
# Les règles de la section 59 ont été enregistrées dans data/rules\section_59_rule.md
# Les règles de la section 64 ont été enregistrées dans data/rules\section_64_rule.md
# Les règles de la section 65 ont été enregistrées dans data/rules\section_65_rule.md
# Les règles de la section 66 ont été enregistrées dans data/rules\section_66_rule.md
# Les règles de la section 67 ont été enregistrées dans data/rules\section_67_rule.md
# Les règles de la section 69 ont été enregistrées dans data/rules\section_69_rule.md
# Les règles de la section 68 ont été enregistrées dans data/rules\section_68_rule.md
# Les règles de la section 70 ont été enregistrées dans data/rules\section_70_rule.md
# Les règles de la section 71 ont été enregistrées dans data/rules\section_71_rule.md
# Les règles de la section 72 ont été enregistrées dans data/rules\section_72_rule.md
# Les règles de la section 73 ont été enregistrées dans data/rules\section_73_rule.md
# Les règles de la section 74 ont été enregistrées dans data/rules\section_74_rule.md
# Les règles de la section 75 ont été enregistrées dans data/rules\section_75_rule.md
# Les règles de la section 76 ont été enregistrées dans data/rules\section_76_rule.md
# Les règles de la section 77 ont été enregistrées dans data/rules\section_77_rule.md
# Les règles de la section 79 ont été enregistrées dans data/rules\section_79_rule.md
# Les règles de la section 78 ont été enregistrées dans data/rules\section_78_rule.md
# Les règles de la section 80 ont été enregistrées dans data/rules\section_80_rule.md
# Les règles de la section 81 ont été enregistrées dans data/rules\section_81_rule.md
# Les règles de la section 83 ont été enregistrées dans data/rules\section_83_rule.md
# Les règles de la section 85 ont été enregistrées dans data/rules\section_85_rule.md
# Les règles de la section 82 ont été enregistrées dans data/rules\section_82_rule.md
# Les règles de la section 84 ont été enregistrées dans data/rules\section_84_rule.md
# Les règles de la section 86 ont été enregistrées dans data/rules\section_86_rule.md
# Les règles de la section 87 ont été enregistrées dans data/rules\section_87_rule.md
# Les règles de la section 88 ont été enregistrées dans data/rules\section_88_rule.md
# Les règles de la section 89 ont été enregistrées dans data/rules\section_89_rule.md
# Les règles de la section 90 ont été enregistrées dans data/rules\section_90_rule.md
# Les règles de la section 92 ont été enregistrées dans data/rules\section_92_rule.md
# Les règles de la section 91 ont été enregistrées dans data/rules\section_91_rule.md
# Les règles de la section 93 ont été enregistrées dans data/rules\section_93_rule.md
# Les règles de la section 94 ont été enregistrées dans data/rules\section_94_rule.md
# Les règles de la section 95 ont été enregistrées dans data/rules\section_95_rule.md
# Les règles de la section 96 ont été enregistrées dans data/rules\section_96_rule.md
# Les règles de la section 97 ont été enregistrées dans data/rules\section_97_rule.md
# Les règles de la section 99 ont été enregistrées dans data/rules\section_99_rule.md
# Les règles de la section 100 ont été enregistrées dans data/rules\section_100_rule.md
# Les règles de la section 101 ont été enregistrées dans data/rules\section_101_rule.md
# Les règles de la section 98 ont été enregistrées dans data/rules\section_98_rule.md
# Les règles de la section 102 ont été enregistrées dans data/rules\section_102_rule.md
# Les règles de la section 103 ont été enregistrées dans data/rules\section_103_rule.md
# Les règles de la section 104 ont été enregistrées dans data/rules\section_104_rule.md
# Les règles de la section 105 ont été enregistrées dans data/rules\section_105_rule.md
# Les règles de la section 108 ont été enregistrées dans data/rules\section_108_rule.md
# Les règles de la section 106 ont été enregistrées dans data/rules\section_106_rule.md
# Les règles de la section 107 ont été enregistrées dans data/rules\section_107_rule.md
# Les règles de la section 109 ont été enregistrées dans data/rules\section_109_rule.md
# Les règles de la section 111 ont été enregistrées dans data/rules\section_111_rule.md
# Les règles de la section 110 ont été enregistrées dans data/rules\section_110_rule.md
# Les règles de la section 112 ont été enregistrées dans data/rules\section_112_rule.md
# Les règles de la section 114 ont été enregistrées dans data/rules\section_114_rule.md
# Les règles de la section 113 ont été enregistrées dans data/rules\section_113_rule.md
# Les règles de la section 115 ont été enregistrées dans data/rules\section_115_rule.md
# Les règles de la section 116 ont été enregistrées dans data/rules\section_116_rule.md
# Les règles de la section 117 ont été enregistrées dans data/rules\section_117_rule.md
# Les règles de la section 118 ont été enregistrées dans data/rules\section_118_rule.md
# Les règles de la section 119 ont été enregistrées dans data/rules\section_119_rule.md
# Les règles de la section 120 ont été enregistrées dans data/rules\section_120_rule.md
# Les règles de la section 121 ont été enregistrées dans data/rules\section_121_rule.md
# Les règles de la section 123 ont été enregistrées dans data/rules\section_123_rule.md
# Les règles de la section 122 ont été enregistrées dans data/rules\section_122_rule.md
# Les règles de la section 125 ont été enregistrées dans data/rules\section_125_rule.md
# Les règles de la section 124 ont été enregistrées dans data/rules\section_124_rule.md
# Les règles de la section 126 ont été enregistrées dans data/rules\section_126_rule.md
# Les règles de la section 127 ont été enregistrées dans data/rules\section_127_rule.md
# Les règles de la section 128 ont été enregistrées dans data/rules\section_128_rule.md
# Les règles de la section 129 ont été enregistrées dans data/rules\section_129_rule.md
# Les règles de la section 130 ont été enregistrées dans data/rules\section_130_rule.md
# Les règles de la section 131 ont été enregistrées dans data/rules\section_131_rule.md
# Les règles de la section 132 ont été enregistrées dans data/rules\section_132_rule.md
# Les règles de la section 134 ont été enregistrées dans data/rules\section_134_rule.md
# Les règles de la section 133 ont été enregistrées dans data/rules\section_133_rule.md
# Les règles de la section 135 ont été enregistrées dans data/rules\section_135_rule.md
# Les règles de la section 137 ont été enregistrées dans data/rules\section_137_rule.md
# Les règles de la section 136 ont été enregistrées dans data/rules\section_136_rule.md
# Les règles de la section 139 ont été enregistrées dans data/rules\section_139_rule.md
# Les règles de la section 138 ont été enregistrées dans data/rules\section_138_rule.md
# Les règles de la section 140 ont été enregistrées dans data/rules\section_140_rule.md
# Les règles de la section 141 ont été enregistrées dans data/rules\section_141_rule.md
# Les règles de la section 142 ont été enregistrées dans data/rules\section_142_rule.md
# Les règles de la section 143 ont été enregistrées dans data/rules\section_143_rule.md
# Les règles de la section 145 ont été enregistrées dans data/rules\section_145_rule.md
# Les règles de la section 144 ont été enregistrées dans data/rules\section_144_rule.md
# Les règles de la section 146 ont été enregistrées dans data/rules\section_146_rule.md
# Les règles de la section 147 ont été enregistrées dans data/rules\section_147_rule.md
# Les règles de la section 148 ont été enregistrées dans data/rules\section_148_rule.md
# Les règles de la section 149 ont été enregistrées dans data/rules\section_149_rule.md
# Les règles de la section 151 ont été enregistrées dans data/rules\section_151_rule.md
# Les règles de la section 150 ont été enregistrées dans data/rules\section_150_rule.md
# Les règles de la section 153 ont été enregistrées dans data/rules\section_153_rule.md
# Les règles de la section 152 ont été enregistrées dans data/rules\section_152_rule.md
# Les règles de la section 154 ont été enregistrées dans data/rules\section_154_rule.md
# Les règles de la section 155 ont été enregistrées dans data/rules\section_155_rule.md
# Les règles de la section 156 ont été enregistrées dans data/rules\section_156_rule.md
# Les règles de la section 158 ont été enregistrées dans data/rules\section_158_rule.md
# Les règles de la section 157 ont été enregistrées dans data/rules\section_157_rule.md
# Les règles de la section 159 ont été enregistrées dans data/rules\section_159_rule.md
# Les règles de la section 162 ont été enregistrées dans data/rules\section_162_rule.md
# Les règles de la section 161 ont été enregistrées dans data/rules\section_161_rule.md
# Les règles de la section 163 ont été enregistrées dans data/rules\section_163_rule.md
# Les règles de la section 164 ont été enregistrées dans data/rules\section_164_rule.md
# Les règles de la section 160 ont été enregistrées dans data/rules\section_160_rule.md
# Les règles de la section 166 ont été enregistrées dans data/rules\section_166_rule.md
# Les règles de la section 165 ont été enregistrées dans data/rules\section_165_rule.md
# Les règles de la section 167 ont été enregistrées dans data/rules\section_167_rule.md
# Les règles de la section 168 ont été enregistrées dans data/rules\section_168_rule.md
# Les règles de la section 169 ont été enregistrées dans data/rules\section_169_rule.md
# Les règles de la section 170 ont été enregistrées dans data/rules\section_170_rule.md
# Les règles de la section 171 ont été enregistrées dans data/rules\section_171_rule.md
# Les règles de la section 172 ont été enregistrées dans data/rules\section_172_rule.md
# Les règles de la section 174 ont été enregistrées dans data/rules\section_174_rule.md
# Les règles de la section 173 ont été enregistrées dans data/rules\section_173_rule.md
# Les règles de la section 176 ont été enregistrées dans data/rules\section_176_rule.md
# Les règles de la section 177 ont été enregistrées dans data/rules\section_177_rule.md
# Les règles de la section 175 ont été enregistrées dans data/rules\section_175_rule.md
# Les règles de la section 178 ont été enregistrées dans data/rules\section_178_rule.md
# Les règles de la section 181 ont été enregistrées dans data/rules\section_181_rule.md
# Les règles de la section 179 ont été enregistrées dans data/rules\section_179_rule.md
# Les règles de la section 180 ont été enregistrées dans data/rules\section_180_rule.md
# Les règles de la section 182 ont été enregistrées dans data/rules\section_182_rule.md
# Les règles de la section 183 ont été enregistrées dans data/rules\section_183_rule.md
# Les règles de la section 185 ont été enregistrées dans data/rules\section_185_rule.md
# Les règles de la section 186 ont été enregistrées dans data/rules\section_186_rule.md
# Les règles de la section 184 ont été enregistrées dans data/rules\section_184_rule.md
# Les règles de la section 187 ont été enregistrées dans data/rules\section_187_rule.md
# Les règles de la section 188 ont été enregistrées dans data/rules\section_188_rule.md
# Les règles de la section 189 ont été enregistrées dans data/rules\section_189_rule.md
# Les règles de la section 192 ont été enregistrées dans data/rules\section_192_rule.md
# Les règles de la section 191 ont été enregistrées dans data/rules\section_191_rule.md
# Les règles de la section 190 ont été enregistrées dans data/rules\section_190_rule.md
# Les règles de la section 193 ont été enregistrées dans data/rules\section_193_rule.md
# Les règles de la section 194 ont été enregistrées dans data/rules\section_194_rule.md
# Les règles de la section 195 ont été enregistrées dans data/rules\section_195_rule.md
# Les règles de la section 196 ont été enregistrées dans data/rules\section_196_rule.md
# Les règles de la section 197 ont été enregistrées dans data/rules\section_197_rule.md
# Les règles de la section 199 ont été enregistrées dans data/rules\section_199_rule.md
# Les règles de la section 198 ont été enregistrées dans data/rules\section_198_rule.md
# Les règles de la section 200 ont été enregistrées dans data/rules\section_200_rule.md
# Les règles de la section 203 ont été enregistrées dans data/rules\section_203_rule.md
# Les règles de la section 201 ont été enregistrées dans data/rules\section_201_rule.md
# Les règles de la section 202 ont été enregistrées dans data/rules\section_202_rule.md
# Les règles de la section 204 ont été enregistrées dans data/rules\section_204_rule.md
# Les règles de la section 205 ont été enregistrées dans data/rules\section_205_rule.md
# Les règles de la section 206 ont été enregistrées dans data/rules\section_206_rule.md
# Les règles de la section 207 ont été enregistrées dans data/rules\section_207_rule.md
# Les règles de la section 208 ont été enregistrées dans data/rules\section_208_rule.md
# Les règles de la section 209 ont été enregistrées dans data/rules\section_209_rule.md
# Les règles de la section 210 ont été enregistrées dans data/rules\section_210_rule.md
# Les règles de la section 211 ont été enregistrées dans data/rules\section_211_rule.md
# Les règles de la section 212 ont été enregistrées dans data/rules\section_212_rule.md
# Les règles de la section 213 ont été enregistrées dans data/rules\section_213_rule.md
# Les règles de la section 214 ont été enregistrées dans data/rules\section_214_rule.md
# Les règles de la section 215 ont été enregistrées dans data/rules\section_215_rule.md
# Les règles de la section 218 ont été enregistrées dans data/rules\section_218_rule.md
# Les règles de la section 216 ont été enregistrées dans data/rules\section_216_rule.md
# Les règles de la section 219 ont été enregistrées dans data/rules\section_219_rule.md
# Les règles de la section 217 ont été enregistrées dans data/rules\section_217_rule.md
# Les règles de la section 222 ont été enregistrées dans data/rules\section_222_rule.md
# Les règles de la section 223 ont été enregistrées dans data/rules\section_223_rule.md
# Les règles de la section 224 ont été enregistrées dans data/rules\section_224_rule.md
# Les règles de la section 220 ont été enregistrées dans data/rules\section_220_rule.md
# Les règles de la section 221 ont été enregistrées dans data/rules\section_221_rule.md
# Les règles de la section 225 ont été enregistrées dans data/rules\section_225_rule.md
# Les règles de la section 226 ont été enregistrées dans data/rules\section_226_rule.md
# Les règles de la section 228 ont été enregistrées dans data/rules\section_228_rule.md
# Les règles de la section 227 ont été enregistrées dans data/rules\section_227_rule.md
# Les règles de la section 229 ont été enregistrées dans data/rules\section_229_rule.md
# Les règles de la section 230 ont été enregistrées dans data/rules\section_230_rule.md
# Les règles de la section 232 ont été enregistrées dans data/rules\section_232_rule.md
# Les règles de la section 233 ont été enregistrées dans data/rules\section_233_rule.md
# Les règles de la section 231 ont été enregistrées dans data/rules\section_231_rule.md
# Les règles de la section 237 ont été enregistrées dans data/rules\section_237_rule.md
# Les règles de la section 236 ont été enregistrées dans data/rules\section_236_rule.md
# Les règles de la section 235 ont été enregistrées dans data/rules\section_235_rule.md
# Les règles de la section 234 ont été enregistrées dans data/rules\section_234_rule.md
# Les règles de la section 238 ont été enregistrées dans data/rules\section_238_rule.md
# Les règles de la section 239 ont été enregistrées dans data/rules\section_239_rule.md
# Les règles de la section 240 ont été enregistrées dans data/rules\section_240_rule.md
# Les règles de la section 241 ont été enregistrées dans data/rules\section_241_rule.md
# Les règles de la section 242 ont été enregistrées dans data/rules\section_242_rule.md
# Les règles de la section 245 ont été enregistrées dans data/rules\section_245_rule.md
# Les règles de la section 246 ont été enregistrées dans data/rules\section_246_rule.md
# Les règles de la section 243 ont été enregistrées dans data/rules\section_243_rule.md
# Les règles de la section 247 ont été enregistrées dans data/rules\section_247_rule.md
# Les règles de la section 248 ont été enregistrées dans data/rules\section_248_rule.md
# Les règles de la section 249 ont été enregistrées dans data/rules\section_249_rule.md
# Les règles de la section 244 ont été enregistrées dans data/rules\section_244_rule.md
# Les règles de la section 250 ont été enregistrées dans data/rules\section_250_rule.md
# Les règles de la section 251 ont été enregistrées dans data/rules\section_251_rule.md
# Les règles de la section 252 ont été enregistrées dans data/rules\section_252_rule.md
# Les règles de la section 253 ont été enregistrées dans data/rules\section_253_rule.md
# Les règles de la section 254 ont été enregistrées dans data/rules\section_254_rule.md
# Les règles de la section 255 ont été enregistrées dans data/rules\section_255_rule.md
# Les règles de la section 257 ont été enregistrées dans data/rules\section_257_rule.md
# Les règles de la section 258 ont été enregistrées dans data/rules\section_258_rule.md
# Les règles de la section 259 ont été enregistrées dans data/rules\section_259_rule.md
# Les règles de la section 256 ont été enregistrées dans data/rules\section_256_rule.md
# Les règles de la section 260 ont été enregistrées dans data/rules\section_260_rule.md
# Les règles de la section 261 ont été enregistrées dans data/rules\section_261_rule.md
# Les règles de la section 263 ont été enregistrées dans data/rules\section_263_rule.md
# Les règles de la section 264 ont été enregistrées dans data/rules\section_264_rule.md
# Les règles de la section 265 ont été enregistrées dans data/rules\section_265_rule.md
# Les règles de la section 262 ont été enregistrées dans data/rules\section_262_rule.md
# Les règles de la section 266 ont été enregistrées dans data/rules\section_266_rule.md
# Les règles de la section 267 ont été enregistrées dans data/rules\section_267_rule.md
# Les règles de la section 268 ont été enregistrées dans data/rules\section_268_rule.md
# Les règles de la section 269 ont été enregistrées dans data/rules\section_269_rule.md
# Les règles de la section 270 ont été enregistrées dans data/rules\section_270_rule.md
# Les règles de la section 271 ont été enregistrées dans data/rules\section_271_rule.md
# Les règles de la section 272 ont été enregistrées dans data/rules\section_272_rule.md
# Les règles de la section 273 ont été enregistrées dans data/rules\section_273_rule.md
# Les règles de la section 275 ont été enregistrées dans data/rules\section_275_rule.md
# Les règles de la section 274 ont été enregistrées dans data/rules\section_274_rule.md
# Les règles de la section 276 ont été enregistrées dans data/rules\section_276_rule.md
# Les règles de la section 277 ont été enregistrées dans data/rules\section_277_rule.md
# Les règles de la section 278 ont été enregistrées dans data/rules\section_278_rule.md
# Les règles de la section 279 ont été enregistrées dans data/rules\section_279_rule.md
# Les règles de la section 280 ont été enregistrées dans data/rules\section_280_rule.md
# Les règles de la section 281 ont été enregistrées dans data/rules\section_281_rule.md
# Les règles de la section 284 ont été enregistrées dans data/rules\section_284_rule.md
# Les règles de la section 283 ont été enregistrées dans data/rules\section_283_rule.md
# Les règles de la section 285 ont été enregistrées dans data/rules\section_285_rule.md
# Les règles de la section 282 ont été enregistrées dans data/rules\section_282_rule.md
# Les règles de la section 286 ont été enregistrées dans data/rules\section_286_rule.md
# Les règles de la section 288 ont été enregistrées dans data/rules\section_288_rule.md
# Les règles de la section 287 ont été enregistrées dans data/rules\section_287_rule.md
# Les règles de la section 290 ont été enregistrées dans data/rules\section_290_rule.md
# Les règles de la section 291 ont été enregistrées dans data/rules\section_291_rule.md
# Les règles de la section 289 ont été enregistrées dans data/rules\section_289_rule.md
# Les règles de la section 292 ont été enregistrées dans data/rules\section_292_rule.md
# Les règles de la section 293 ont été enregistrées dans data/rules\section_293_rule.md
# Les règles de la section 294 ont été enregistrées dans data/rules\section_294_rule.md
# Les règles de la section 296 ont été enregistrées dans data/rules\section_296_rule.md
# Les règles de la section 297 ont été enregistrées dans data/rules\section_297_rule.md
# Les règles de la section 299 ont été enregistrées dans data/rules\section_299_rule.md
# Les règles de la section 298 ont été enregistrées dans data/rules\section_298_rule.md
# Les règles de la section 295 ont été enregistrées dans data/rules\section_295_rule.md
# Les règles de la section 300 ont été enregistrées dans data/rules\section_300_rule.md
# Les règles de la section 303 ont été enregistrées dans data/rules\section_303_rule.md
# Les règles de la section 301 ont été enregistrées dans data/rules\section_301_rule.md
# Les règles de la section 302 ont été enregistrées dans data/rules\section_302_rule.md
# Les règles de la section 304 ont été enregistrées dans data/rules\section_304_rule.md
# Les règles de la section 305 ont été enregistrées dans data/rules\section_305_rule.md
# Les règles de la section 307 ont été enregistrées dans data/rules\section_307_rule.md
# Les règles de la section 306 ont été enregistrées dans data/rules\section_306_rule.md
# Les règles de la section 308 ont été enregistrées dans data/rules\section_308_rule.md
# Les règles de la section 309 ont été enregistrées dans data/rules\section_309_rule.md
# Les règles de la section 310 ont été enregistrées dans data/rules\section_310_rule.md
# Les règles de la section 311 ont été enregistrées dans data/rules\section_311_rule.md
# Les règles de la section 312 ont été enregistrées dans data/rules\section_312_rule.md
# Les règles de la section 313 ont été enregistrées dans data/rules\section_313_rule.md
# Les règles de la section 314 ont été enregistrées dans data/rules\section_314_rule.md
# Les règles de la section 315 ont été enregistrées dans data/rules\section_315_rule.md
# Les règles de la section 316 ont été enregistrées dans data/rules\section_316_rule.md
# Les règles de la section 317 ont été enregistrées dans data/rules\section_317_rule.md
# Les règles de la section 318 ont été enregistrées dans data/rules\section_318_rule.md
# Les règles de la section 319 ont été enregistrées dans data/rules\section_319_rule.md
# Les règles de la section 322 ont été enregistrées dans data/rules\section_322_rule.md
# Les règles de la section 320 ont été enregistrées dans data/rules\section_320_rule.md
# Les règles de la section 323 ont été enregistrées dans data/rules\section_323_rule.md
# Les règles de la section 321 ont été enregistrées dans data/rules\section_321_rule.md
# Les règles de la section 324 ont été enregistrées dans data/rules\section_324_rule.md
# Les règles de la section 325 ont été enregistrées dans data/rules\section_325_rule.md
# Les règles de la section 327 ont été enregistrées dans data/rules\section_327_rule.md
# Les règles de la section 326 ont été enregistrées dans data/rules\section_326_rule.md
# Les règles de la section 328 ont été enregistrées dans data/rules\section_328_rule.md
# Les règles de la section 329 ont été enregistrées dans data/rules\section_329_rule.md
# Les règles de la section 330 ont été enregistrées dans data/rules\section_330_rule.md
# Les règles de la section 332 ont été enregistrées dans data/rules\section_332_rule.md
# Les règles de la section 331 ont été enregistrées dans data/rules\section_331_rule.md
# Les règles de la section 333 ont été enregistrées dans data/rules\section_333_rule.md
# Les règles de la section 334 ont été enregistrées dans data/rules\section_334_rule.md
# Les règles de la section 336 ont été enregistrées dans data/rules\section_336_rule.md
# Les règles de la section 338 ont été enregistrées dans data/rules\section_338_rule.md
# Les règles de la section 337 ont été enregistrées dans data/rules\section_337_rule.md
# Les règles de la section 339 ont été enregistrées dans data/rules\section_339_rule.md
# Les règles de la section 335 ont été enregistrées dans data/rules\section_335_rule.md
# Les règles de la section 340 ont été enregistrées dans data/rules\section_340_rule.md
# Les règles de la section 341 ont été enregistrées dans data/rules\section_341_rule.md
# Les règles de la section 342 ont été enregistrées dans data/rules\section_342_rule.md
# Les règles de la section 344 ont été enregistrées dans data/rules\section_344_rule.md
# Les règles de la section 343 ont été enregistrées dans data/rules\section_343_rule.md
# Les règles de la section 346 ont été enregistrées dans data/rules\section_346_rule.md
# Les règles de la section 347 ont été enregistrées dans data/rules\section_347_rule.md
# Les règles de la section 348 ont été enregistrées dans data/rules\section_348_rule.md
# Les règles de la section 350 ont été enregistrées dans data/rules\section_350_rule.md
# Les règles de la section 351 ont été enregistrées dans data/rules\section_351_rule.md
# Les règles de la section 352 ont été enregistrées dans data/rules\section_352_rule.md
# Les règles de la section 353 ont été enregistrées dans data/rules\section_353_rule.md
# Les règles de la section 349 ont été enregistrées dans data/rules\section_349_rule.md
# Les règles de la section 345 ont été enregistrées dans data/rules\section_345_rule.md
# Les règles de la section 354 ont été enregistrées dans data/rules\section_354_rule.md
# Les règles de la section 356 ont été enregistrées dans data/rules\section_356_rule.md
# Les règles de la section 357 ont été enregistrées dans data/rules\section_357_rule.md
# Les règles de la section 358 ont été enregistrées dans data/rules\section_358_rule.md
# Les règles de la section 355 ont été enregistrées dans data/rules\section_355_rule.md
# Les règles de la section 359 ont été enregistrées dans data/rules\section_359_rule.md
# Les règles de la section 360 ont été enregistrées dans data/rules\section_360_rule.md
# Les règles de la section 363 ont été enregistrées dans data/rules\section_363_rule.md
# Les règles de la section 361 ont été enregistrées dans data/rules\section_361_rule.md
# Les règles de la section 362 ont été enregistrées dans data/rules\section_362_rule.md
# Les règles de la section 364 ont été enregistrées dans data/rules\section_364_rule.md
# Les règles de la section 365 ont été enregistrées dans data/rules\section_365_rule.md
# Les règles de la section 368 ont été enregistrées dans data/rules\section_368_rule.md
# Les règles de la section 369 ont été enregistrées dans data/rules\section_369_rule.md
# Les règles de la section 367 ont été enregistrées dans data/rules\section_367_rule.md
# Les règles de la section 366 ont été enregistrées dans data/rules\section_366_rule.md
# Les règles de la section 371 ont été enregistrées dans data/rules\section_371_rule.md
# Les règles de la section 370 ont été enregistrées dans data/rules\section_370_rule.md
# Les règles de la section 372 ont été enregistrées dans data/rules\section_372_rule.md
# Les règles de la section 374 ont été enregistrées dans data/rules\section_374_rule.md
# Les règles de la section 375 ont été enregistrées dans data/rules\section_375_rule.md
# Les règles de la section 373 ont été enregistrées dans data/rules\section_373_rule.md
# Les règles de la section 376 ont été enregistrées dans data/rules\section_376_rule.md
# Les règles de la section 377 ont été enregistrées dans data/rules\section_377_rule.md
# Les règles de la section 378 ont été enregistrées dans data/rules\section_378_rule.md
# Les règles de la section 379 ont été enregistrées dans data/rules\section_379_rule.md
# Les règles de la section 380 ont été enregistrées dans data/rules\section_380_rule.md
# Les règles de la section 384 ont été enregistrées dans data/rules\section_384_rule.md
# Les règles de la section 382 ont été enregistrées dans data/rules\section_382_rule.md
# Les règles de la section 383 ont été enregistrées dans data/rules\section_383_rule.md
# Les règles de la section 381 ont été enregistrées dans data/rules\section_381_rule.md
# Les règles de la section 385 ont été enregistrées dans data/rules\section_385_rule.md
# Les règles de la section 386 ont été enregistrées dans data/rules\section_386_rule.md
# Les règles de la section 388 ont été enregistrées dans data/rules\section_388_rule.md
# Les règles de la section 387 ont été enregistrées dans data/rules\section_387_rule.md
# Les règles de la section 389 ont été enregistrées dans data/rules\section_389_rule.md
# Les règles de la section 390 ont été enregistrées dans data/rules\section_390_rule.md
# Les règles de la section 391 ont été enregistrées dans data/rules\section_391_rule.md
# Les règles de la section 392 ont été enregistrées dans data/rules\section_392_rule.md
# Les règles de la section 393 ont été enregistrées dans data/rules\section_393_rule.md
# Les règles de la section 394 ont été enregistrées dans data/rules\section_394_rule.md
# Les règles de la section 396 ont été enregistrées dans data/rules\section_396_rule.md
# Les règles de la section 397 ont été enregistrées dans data/rules\section_397_rule.md
# Les règles de la section 395 ont été enregistrées dans data/rules\section_395_rule.md
# Les règles de la section 399 ont été enregistrées dans data/rules\section_399_rule.md
# Les règles de la section 398 ont été enregistrées dans data/rules\section_398_rule.md
# Les règles de la section 400 ont été enregistrées dans data/rules\section_400_rule.md
